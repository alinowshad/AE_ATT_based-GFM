# %%
! pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /opt/conda/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow-addons) (3.0.9)

# %%
! pip install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tslearn) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from tslearn) (1.11.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from tslearn) (0.57.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from tslearn) (1.3.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->tslearn) (0.40.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->tslearn) (3.1.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
import tensorflow_addons as tfa
from math import pi, ceil

import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.models import Model
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
ndim=20

# %%
class AEBase(keras.Model):
    def __init__(self, **kwargs):
        super(AEBase, self).__init__(**kwargs)
        self.encoder = self.construct_encoder()
        self.decoder = self.construct_decoder()
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.mean_squared_error(data, reconstruction), axis=(0, 1)
                )
            )
        grads = tape.gradient(reconstruction_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(reconstruction_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
        }

# %%
import tensorflow.keras as keras
from tensorflow.keras.layers import Input, LSTM, Dense, RepeatVector, Attention
from tensorflow.keras import layers

class LSTMAEWithAttention(AEBase):
    def __init__(self, latent_dim=12, encoder_hiddens=[256, 128, 64], decoder_hiddens=[64, 128, 256], series_len=None):
        self.latent_dim = latent_dim
        self.encoder_hiddens = encoder_hiddens
        self.decoder_hiddens = decoder_hiddens
        self.series_len = series_len
        super(LSTMAEWithAttention, self).__init__()

    def construct_encoder(self):
        encoder_inputs = Input((None, self.series_len))
        #masked_seq = layers.Masking(mask_value=0.0)(encoder_inputs)  # Mask any time step with value 0.0

        x = LSTM(self.encoder_hiddens[0], return_sequences=True)(encoder_inputs)
        for i in range(1, len(self.encoder_hiddens) - 1):
            x = LSTM(self.encoder_hiddens[i], return_sequences=True)(x)
        
        # Add an attention mechanism here
        attention = Attention()([x, x, x])  # Apply self-attention to the encoder outputs
        merged = layers.Concatenate(axis=-1)([x, attention])
        
        x = LSTM(self.encoder_hiddens[-1])(merged)

        x = Dense(self.latent_dim)(x)
        encoder = keras.Model(encoder_inputs, x, name="encoder")
        return encoder

    def construct_decoder(self):
        latent_inputs = Input(shape=(self.latent_dim,))
        x = RepeatVector(1)(latent_inputs)

        for h in self.decoder_hiddens:
            x = LSTM(h, return_sequences=True)(x)
        
        # Add an attention mechanism here
        attention = Attention()([x, x, x])  # Apply self-attention to the decoder outputs
        merged = layers.Concatenate(axis=-1)([x, attention])

        decoder_outputs = TimeDistributed(Dense(self.series_len))(merged)
        decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
        return decoder

# %%
nn5 = pd.read_csv("/kaggle/input/nn5-dataset/nn51.csv", header=None)
nn5.head()
# Out:
#          0          1          2          3          4          5    \
# 0  13.407029  14.725057  20.564059  34.708050  26.629819  16.609977
# 1  11.550454  13.591270  15.036848  21.570295  19.444444   0.000000
# 2   5.640590  14.399093  24.418934  28.784014  20.620748  13.803855
# 3  13.180272   8.446712  19.515306  28.883220  19.472789   0.000000
# 4   9.778912  10.813492  21.612812  38.520408  24.744898  12.329932
#
#          6          7          8          9    ...        781        782  \
# 0  15.320295  11.607143  19.883787  23.767007  ...  50.141723  33.701814
# 1   9.722222  12.244898  15.504535  18.934240  ...  34.665533  13.988095
# 2  11.536281  10.742630  14.824263  25.212585  ...  38.364512  17.928005
# 3   7.355442  10.827664  15.617914  21.159297  ...  31.420068  17.276077
# 4  12.996032  11.040249   7.950680  19.515306  ...  33.758503  18.990930
#
#          783        784        785        786        787        788  \
# 0  28.656463  26.417234  27.253401  44.373583  65.206916  49.744898
# 1  13.874717  16.326531  17.488662  20.663265  27.097506  32.171202
# 2  18.041383  16.978458  22.293084  36.522109  42.786281  39.271542
# 3  15.674603  12.471655  17.928005  25.028345  45.308957  32.242063
# 4  16.865079  16.000567  15.079365  20.833333  40.646259  33.304989
#
#          789        790
# 0  34.481293  32.667234
# 1  13.676304  16.369048
# 2  17.446145  17.148526
# 3  15.943878  16.638322
# 4  16.666667  14.101474
#
# [5 rows x 791 columns]

# %%
from datetime import datetime, timedelta
start_date = datetime(1996, 3, 18)

date_range = [start_date + timedelta(days=i) for i in range(nn5.shape[1])]

# Convert the date range to days of the week
days_of_week = [date.strftime('%A') for date in date_range]
nn5.columns = days_of_week

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame with columns as days of the week

# Function to replace zeros with the median of non-zero values for each day of the week
def replace_zeros_with_median(series):
    # Iterate over unique days of the week
    for day in nn5.columns:
        # Extract non-zero values for the specific day
        non_zero_values = series[series.index == day].replace(0, np.nan).dropna()
        
        # Calculate the median of non-zero values
        median_value = non_zero_values.median()
        
        # Replace zeros with the median for the specific day
        series.loc[series.index == day] = series.loc[series.index == day].replace(0, median_value)

# Apply the function to each row of the DataFrame
nn5.apply(replace_zeros_with_median, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 106    None
# 107    None
# 108    None
# 109    None
# 110    None
# Length: 111, dtype: object

# %%
def preprocessing(data):
    ts_train = []

    for i in range(data.shape[0]):
        # for normalization of each series
        # mean_temp=np.mean(np.array(list(data.iloc[i][6:].dropna())))
        # temp = np.array(list(data.iloc[i][6:].dropna())/mean_temp)
        # temp = np.array(list(data.iloc[i][6:].dropna()))
        # temp=np.log(temp + 1)
        temp=np.array(list(data.iloc[i].dropna()))
        temp = temp[:-56]
        temp=temp.reshape(1,len(temp),1)
        temp2 = TimeSeriesScalerMeanVariance().fit_transform(temp)
        # temp = TimeSeriesScalerMeanVariance().fit_transform(np.array(list(m3.iloc[0][6:].dropna())).reshape(-1,1))

        ts_train.append(temp2.reshape(-1,1))

    return ts_train

# %%
dataset_nn5 = preprocessing(nn5)
dataset_nn5 = np.array(dataset_nn5)

# %%
max_seq_length_nn5 = max(len(seq) for seq in dataset_nn5)

# %%
reshaped_array_nn5 = dataset_nn5.reshape(dataset_nn5.shape[0], 1, dataset_nn5.shape[1])

# %%
print(reshaped_array_nn5.shape)
# Out:
# (111, 1, 735)

# %%
dim = [8, 16, 32]

# %%
for item in dim:
    print("****************************************************")
    print("Checking the dimension: ", item)
    print("****************************************************")
    ae_nn5=LSTMAEWithAttention(latent_dim=item, series_len=max_seq_length_nn5)
    ae_nn5.compile(optimizer=keras.optimizers.Adam(),loss="mse")
    ae_nn5.fit(reshaped_array_nn5, epochs=100, batch_size=10)
    Features_nn5 = ae_nn5.encoder(reshaped_array_nn5)
    path = "Features_nn5_LSTM_"+str(item)+".csv"
    np.savetxt(path, Features_nn5, delimiter=",")
# Out:
# ****************************************************
# Checking the dimension:  8
# ****************************************************
# Epoch 1/100
# 12/12 [==============================] - 3s 194ms/step - loss: 9.8244 - reconstruction_loss: 9.1351
# Epoch 2/100
# 12/12 [==============================] - 2s 191ms/step - loss: 8.6876 - reconstruction_loss: 7.4474
# Epoch 3/100
# 12/12 [==============================] - 2s 195ms/step - loss: 4.7861 - reconstruction_loss: 4.3852
# Epoch 4/100
# 12/12 [==============================] - 2s 190ms/step - loss: 4.1714 - reconstruction_loss: 3.8730
# Epoch 5/100
# 12/12 [==============================] - 2s 185ms/step - loss: 4.1428 - reconstruction_loss: 3.7610
# Epoch 6/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.8969 - reconstruction_loss: 3.7167
# Epoch 7/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.6748 - reconstruction_loss: 3.6809
# Epoch 8/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.9037 - reconstruction_loss: 3.6807
# Epoch 9/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7418 - reconstruction_loss: 3.6809
# Epoch 10/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.7455 - reconstruction_loss: 3.6820
# Epoch 11/100
# 12/12 [==============================] - 2s 178ms/step - loss: 3.9673 - reconstruction_loss: 3.6764
# Epoch 12/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.8349 - reconstruction_loss: 3.6605
# Epoch 13/100
# 12/12 [==============================] - 2s 184ms/step - loss: 4.0548 - reconstruction_loss: 3.6175
# Epoch 14/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.9212 - reconstruction_loss: 3.6139
# Epoch 15/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8695 - reconstruction_loss: 3.6059
# Epoch 16/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.9085 - reconstruction_loss: 3.6046
# Epoch 17/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.7422 - reconstruction_loss: 3.6033
# Epoch 18/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7789 - reconstruction_loss: 3.5999
# Epoch 19/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.9143 - reconstruction_loss: 3.5952
# Epoch 20/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.6789 - reconstruction_loss: 3.5952
# Epoch 21/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.9371 - reconstruction_loss: 3.5962
# Epoch 22/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.7354 - reconstruction_loss: 3.5928
# Epoch 23/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7934 - reconstruction_loss: 3.5935
# Epoch 24/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.7481 - reconstruction_loss: 3.5929
# Epoch 25/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.9318 - reconstruction_loss: 3.5907
# Epoch 26/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.9382 - reconstruction_loss: 3.5885
# Epoch 27/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8491 - reconstruction_loss: 3.5884
# Epoch 28/100
# 12/12 [==============================] - 2s 200ms/step - loss: 3.9760 - reconstruction_loss: 3.5887
# Epoch 29/100
# 12/12 [==============================] - 2s 195ms/step - loss: 4.0062 - reconstruction_loss: 3.5860
# Epoch 30/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.7596 - reconstruction_loss: 3.5841
# Epoch 31/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7664 - reconstruction_loss: 3.5839
# Epoch 32/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.9803 - reconstruction_loss: 3.5865
# Epoch 33/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7422 - reconstruction_loss: 3.5861
# Epoch 34/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.7669 - reconstruction_loss: 3.5837
# Epoch 35/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.7062 - reconstruction_loss: 3.5853
# Epoch 36/100
# 12/12 [==============================] - 2s 192ms/step - loss: 3.8338 - reconstruction_loss: 3.5839
# Epoch 37/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.7241 - reconstruction_loss: 3.5827
# Epoch 38/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7433 - reconstruction_loss: 3.5842
# Epoch 39/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.8853 - reconstruction_loss: 3.5823
# Epoch 40/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.9322 - reconstruction_loss: 3.5793
# Epoch 41/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.7101 - reconstruction_loss: 3.5793
# Epoch 42/100
# 12/12 [==============================] - 3s 211ms/step - loss: 4.0638 - reconstruction_loss: 3.5809
# Epoch 43/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.8291 - reconstruction_loss: 3.5791
# Epoch 44/100
# 12/12 [==============================] - 2s 192ms/step - loss: 4.0749 - reconstruction_loss: 3.5774
# Epoch 45/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.8225 - reconstruction_loss: 3.5793
# Epoch 46/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.5909 - reconstruction_loss: 3.5766
# Epoch 47/100
# 12/12 [==============================] - 2s 205ms/step - loss: 3.8201 - reconstruction_loss: 3.5734
# Epoch 48/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.8792 - reconstruction_loss: 3.5719
# Epoch 49/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.7106 - reconstruction_loss: 3.5760
# Epoch 50/100
# 12/12 [==============================] - 2s 204ms/step - loss: 3.7635 - reconstruction_loss: 3.5710
# Epoch 51/100
# 12/12 [==============================] - 2s 201ms/step - loss: 3.7402 - reconstruction_loss: 3.5719
# Epoch 52/100
# 12/12 [==============================] - 2s 204ms/step - loss: 3.6560 - reconstruction_loss: 3.5688
# Epoch 53/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.7619 - reconstruction_loss: 3.5660
# Epoch 54/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.9182 - reconstruction_loss: 3.5640
# Epoch 55/100
# 12/12 [==============================] - 3s 215ms/step - loss: 3.8509 - reconstruction_loss: 3.5623
# Epoch 56/100
# 12/12 [==============================] - 2s 199ms/step - loss: 3.7867 - reconstruction_loss: 3.5616
# Epoch 57/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.8286 - reconstruction_loss: 3.5597
# Epoch 58/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.8713 - reconstruction_loss: 3.5590
# Epoch 59/100
# 12/12 [==============================] - 2s 195ms/step - loss: 3.8305 - reconstruction_loss: 3.5532
# Epoch 60/100
# 12/12 [==============================] - 2s 202ms/step - loss: 3.6030 - reconstruction_loss: 3.5507
# Epoch 61/100
# 12/12 [==============================] - 2s 197ms/step - loss: 4.0433 - reconstruction_loss: 3.5491
# Epoch 62/100
# 12/12 [==============================] - 2s 201ms/step - loss: 3.8000 - reconstruction_loss: 3.5416
# Epoch 63/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.6923 - reconstruction_loss: 3.5351
# Epoch 64/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.6511 - reconstruction_loss: 3.5267
# Epoch 65/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.7407 - reconstruction_loss: 3.5104
# Epoch 66/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.9160 - reconstruction_loss: 3.4899
# Epoch 67/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.6882 - reconstruction_loss: 3.4658
# Epoch 68/100
# 12/12 [==============================] - 3s 212ms/step - loss: 3.8536 - reconstruction_loss: 3.4498
# Epoch 69/100
# 12/12 [==============================] - 2s 200ms/step - loss: 3.7169 - reconstruction_loss: 3.4290
# Epoch 70/100
# 12/12 [==============================] - 2s 208ms/step - loss: 3.5945 - reconstruction_loss: 3.3958
# Epoch 71/100
# 12/12 [==============================] - 3s 213ms/step - loss: 3.5409 - reconstruction_loss: 3.3612
# Epoch 72/100
# 12/12 [==============================] - 3s 211ms/step - loss: 3.4518 - reconstruction_loss: 3.3337
# Epoch 73/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.5499 - reconstruction_loss: 3.3098
# Epoch 74/100
# 12/12 [==============================] - 2s 207ms/step - loss: 3.4506 - reconstruction_loss: 3.2874
# Epoch 75/100
# 12/12 [==============================] - 3s 210ms/step - loss: 3.5327 - reconstruction_loss: 3.2691
# Epoch 76/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.3806 - reconstruction_loss: 3.2432
# Epoch 77/100
# 12/12 [==============================] - 2s 199ms/step - loss: 3.4571 - reconstruction_loss: 3.2341
# Epoch 78/100
# 12/12 [==============================] - 2s 208ms/step - loss: 3.5056 - reconstruction_loss: 3.2167
# Epoch 79/100
# 12/12 [==============================] - 3s 209ms/step - loss: 3.5008 - reconstruction_loss: 3.2103
# Epoch 80/100
# 12/12 [==============================] - 3s 215ms/step - loss: 3.3993 - reconstruction_loss: 3.2221
# Epoch 81/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.3538 - reconstruction_loss: 3.2155
# Epoch 82/100
# 12/12 [==============================] - 2s 192ms/step - loss: 3.3144 - reconstruction_loss: 3.1900
# Epoch 83/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.5045 - reconstruction_loss: 3.1702
# Epoch 84/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.3364 - reconstruction_loss: 3.1560
# Epoch 85/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.3230 - reconstruction_loss: 3.1420
# Epoch 86/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.3981 - reconstruction_loss: 3.1248
# Epoch 87/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.2709 - reconstruction_loss: 3.1248
# Epoch 88/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.3715 - reconstruction_loss: 3.1005
# Epoch 89/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.2342 - reconstruction_loss: 3.0887
# Epoch 90/100
# 12/12 [==============================] - 2s 199ms/step - loss: 3.2594 - reconstruction_loss: 3.0769
# Epoch 91/100
# 12/12 [==============================] - 2s 195ms/step - loss: 3.1531 - reconstruction_loss: 3.0660
# Epoch 92/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.2124 - reconstruction_loss: 3.0534
# Epoch 93/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.1777 - reconstruction_loss: 3.0371
# Epoch 94/100
# 12/12 [==============================] - 2s 199ms/step - loss: 3.1626 - reconstruction_loss: 3.0276
# Epoch 95/100
# 12/12 [==============================] - 2s 204ms/step - loss: 3.3170 - reconstruction_loss: 3.0045
# Epoch 96/100
# 12/12 [==============================] - 2s 200ms/step - loss: 3.2633 - reconstruction_loss: 2.9767
# Epoch 97/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.2084 - reconstruction_loss: 2.9484
# Epoch 98/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.0629 - reconstruction_loss: 2.9229
# Epoch 99/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.2139 - reconstruction_loss: 2.9311
# Epoch 100/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.1475 - reconstruction_loss: 2.9194
# ****************************************************
# Checking the dimension:  16
# ****************************************************
# Epoch 1/100
# 12/12 [==============================] - 2s 196ms/step - loss: 9.8239 - reconstruction_loss: 9.1323
# Epoch 2/100
# 12/12 [==============================] - 2s 191ms/step - loss: 8.5184 - reconstruction_loss: 7.1446
# Epoch 3/100
# 12/12 [==============================] - 2s 199ms/step - loss: 5.0127 - reconstruction_loss: 4.4562
# Epoch 4/100
# 12/12 [==============================] - 2s 192ms/step - loss: 4.2483 - reconstruction_loss: 3.8687
# Epoch 5/100
# 12/12 [==============================] - 2s 187ms/step - loss: 4.3181 - reconstruction_loss: 3.7819
# Epoch 6/100
# 12/12 [==============================] - 2s 191ms/step - loss: 4.0575 - reconstruction_loss: 3.7071
# Epoch 7/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7650 - reconstruction_loss: 3.7042
# Epoch 8/100
# 12/12 [==============================] - 2s 189ms/step - loss: 4.0967 - reconstruction_loss: 3.6691
# Epoch 9/100
# 12/12 [==============================] - 2s 187ms/step - loss: 4.0694 - reconstruction_loss: 3.6582
# Epoch 10/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7441 - reconstruction_loss: 3.6418
# Epoch 11/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8049 - reconstruction_loss: 3.6207
# Epoch 12/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.7818 - reconstruction_loss: 3.6136
# Epoch 13/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.8644 - reconstruction_loss: 3.6092
# Epoch 14/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.6869 - reconstruction_loss: 3.6070
# Epoch 15/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.7817 - reconstruction_loss: 3.6088
# Epoch 16/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.7392 - reconstruction_loss: 3.6080
# Epoch 17/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.9209 - reconstruction_loss: 3.6070
# Epoch 18/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.8172 - reconstruction_loss: 3.6046
# Epoch 19/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7286 - reconstruction_loss: 3.5979
# Epoch 20/100
# 12/12 [==============================] - 2s 177ms/step - loss: 3.8433 - reconstruction_loss: 3.5969
# Epoch 21/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.9810 - reconstruction_loss: 3.5948
# Epoch 22/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7708 - reconstruction_loss: 3.5922
# Epoch 23/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.6653 - reconstruction_loss: 3.5943
# Epoch 24/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8079 - reconstruction_loss: 3.5913
# Epoch 25/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.7224 - reconstruction_loss: 3.5899
# Epoch 26/100
# 12/12 [==============================] - 2s 177ms/step - loss: 3.9380 - reconstruction_loss: 3.5886
# Epoch 27/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7220 - reconstruction_loss: 3.5897
# Epoch 28/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.6412 - reconstruction_loss: 3.5864
# Epoch 29/100
# 12/12 [==============================] - 2s 201ms/step - loss: 3.8396 - reconstruction_loss: 3.5944
# Epoch 30/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.7041 - reconstruction_loss: 3.5861
# Epoch 31/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.9762 - reconstruction_loss: 3.5862
# Epoch 32/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8978 - reconstruction_loss: 3.5857
# Epoch 33/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.8902 - reconstruction_loss: 3.5846
# Epoch 34/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.9879 - reconstruction_loss: 3.5843
# Epoch 35/100
# 12/12 [==============================] - 2s 199ms/step - loss: 3.8635 - reconstruction_loss: 3.5831
# Epoch 36/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7481 - reconstruction_loss: 3.5840
# Epoch 37/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.6453 - reconstruction_loss: 3.5849
# Epoch 38/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.8648 - reconstruction_loss: 3.5817
# Epoch 39/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7174 - reconstruction_loss: 3.5814
# Epoch 40/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.8005 - reconstruction_loss: 3.5803
# Epoch 41/100
# 12/12 [==============================] - 2s 178ms/step - loss: 3.8032 - reconstruction_loss: 3.5790
# Epoch 42/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.8678 - reconstruction_loss: 3.5763
# Epoch 43/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.7130 - reconstruction_loss: 3.5774
# Epoch 44/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.5822 - reconstruction_loss: 3.5756
# Epoch 45/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.7995 - reconstruction_loss: 3.5730
# Epoch 46/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.8940 - reconstruction_loss: 3.5729
# Epoch 47/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.9371 - reconstruction_loss: 3.5781
# Epoch 48/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.7676 - reconstruction_loss: 3.5697
# Epoch 49/100
# 12/12 [==============================] - 2s 209ms/step - loss: 4.1421 - reconstruction_loss: 3.5650
# Epoch 50/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.9313 - reconstruction_loss: 3.5620
# Epoch 51/100
# 12/12 [==============================] - 2s 177ms/step - loss: 3.5700 - reconstruction_loss: 3.5562
# Epoch 52/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.8277 - reconstruction_loss: 3.5523
# Epoch 53/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.7628 - reconstruction_loss: 3.5483
# Epoch 54/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.6898 - reconstruction_loss: 3.5369
# Epoch 55/100
# 12/12 [==============================] - 2s 202ms/step - loss: 3.5417 - reconstruction_loss: 3.5204
# Epoch 56/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.7848 - reconstruction_loss: 3.5073
# Epoch 57/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.6754 - reconstruction_loss: 3.4921
# Epoch 58/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7623 - reconstruction_loss: 3.4815
# Epoch 59/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.5089 - reconstruction_loss: 3.4742
# Epoch 60/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.5333 - reconstruction_loss: 3.4606
# Epoch 61/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.6972 - reconstruction_loss: 3.4631
# Epoch 62/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.8209 - reconstruction_loss: 3.4417
# Epoch 63/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.6561 - reconstruction_loss: 3.4192
# Epoch 64/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.7211 - reconstruction_loss: 3.4063
# Epoch 65/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.5082 - reconstruction_loss: 3.3927
# Epoch 66/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.8012 - reconstruction_loss: 3.3853
# Epoch 67/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.6324 - reconstruction_loss: 3.3778
# Epoch 68/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.5783 - reconstruction_loss: 3.3536
# Epoch 69/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.7258 - reconstruction_loss: 3.3331
# Epoch 70/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.5345 - reconstruction_loss: 3.3113
# Epoch 71/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.4785 - reconstruction_loss: 3.2889
# Epoch 72/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.5328 - reconstruction_loss: 3.2689
# Epoch 73/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.5334 - reconstruction_loss: 3.2537
# Epoch 74/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.5858 - reconstruction_loss: 3.2465
# Epoch 75/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.4822 - reconstruction_loss: 3.2296
# Epoch 76/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.5149 - reconstruction_loss: 3.2181
# Epoch 77/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.4291 - reconstruction_loss: 3.2116
# Epoch 78/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.5877 - reconstruction_loss: 3.2050
# Epoch 79/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.4219 - reconstruction_loss: 3.1930
# Epoch 80/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.3432 - reconstruction_loss: 3.1801
# Epoch 81/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.3330 - reconstruction_loss: 3.1644
# Epoch 82/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.4632 - reconstruction_loss: 3.1403
# Epoch 83/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.3758 - reconstruction_loss: 3.1089
# Epoch 84/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.1898 - reconstruction_loss: 3.0634
# Epoch 85/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.2019 - reconstruction_loss: 3.0069
# Epoch 86/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.1924 - reconstruction_loss: 3.0069
# Epoch 87/100
# 12/12 [==============================] - 2s 178ms/step - loss: 3.2525 - reconstruction_loss: 2.9602
# Epoch 88/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.2004 - reconstruction_loss: 2.9743
# Epoch 89/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.0517 - reconstruction_loss: 2.9554
# Epoch 90/100
# 12/12 [==============================] - 2s 177ms/step - loss: 3.2074 - reconstruction_loss: 2.9183
# Epoch 91/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.0814 - reconstruction_loss: 2.8954
# Epoch 92/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.1767 - reconstruction_loss: 2.8972
# Epoch 93/100
# 12/12 [==============================] - 2s 177ms/step - loss: 2.9813 - reconstruction_loss: 2.8795
# Epoch 94/100
# 12/12 [==============================] - 2s 176ms/step - loss: 3.0690 - reconstruction_loss: 2.8537
# Epoch 95/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.0751 - reconstruction_loss: 2.8452
# Epoch 96/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.0205 - reconstruction_loss: 2.8243
# Epoch 97/100
# 12/12 [==============================] - 2s 186ms/step - loss: 2.9632 - reconstruction_loss: 2.8191
# Epoch 98/100
# 12/12 [==============================] - 2s 182ms/step - loss: 2.9292 - reconstruction_loss: 2.7890
# Epoch 99/100
# 12/12 [==============================] - 2s 179ms/step - loss: 2.9657 - reconstruction_loss: 2.7715
# Epoch 100/100
# 12/12 [==============================] - 2s 175ms/step - loss: 2.9643 - reconstruction_loss: 2.7630
# ****************************************************
# Checking the dimension:  32
# ****************************************************
# Epoch 1/100
# 12/12 [==============================] - 2s 185ms/step - loss: 9.8234 - reconstruction_loss: 9.1334
# Epoch 2/100
# 12/12 [==============================] - 2s 185ms/step - loss: 8.4572 - reconstruction_loss: 7.0396
# Epoch 3/100
# 12/12 [==============================] - 2s 178ms/step - loss: 4.8264 - reconstruction_loss: 4.4628
# Epoch 4/100
# 12/12 [==============================] - 2s 192ms/step - loss: 4.3706 - reconstruction_loss: 3.9066
# Epoch 5/100
# 12/12 [==============================] - 2s 188ms/step - loss: 4.2380 - reconstruction_loss: 3.7762
# Epoch 6/100
# 12/12 [==============================] - 2s 176ms/step - loss: 4.1267 - reconstruction_loss: 3.7020
# Epoch 7/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.9429 - reconstruction_loss: 3.6831
# Epoch 8/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.9506 - reconstruction_loss: 3.6892
# Epoch 9/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.8529 - reconstruction_loss: 3.6750
# Epoch 10/100
# 12/12 [==============================] - 2s 192ms/step - loss: 3.9236 - reconstruction_loss: 3.6733
# Epoch 11/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.8230 - reconstruction_loss: 3.6703
# Epoch 12/100
# 12/12 [==============================] - 2s 187ms/step - loss: 4.0999 - reconstruction_loss: 3.6729
# Epoch 13/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.8634 - reconstruction_loss: 3.6683
# Epoch 14/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.6988 - reconstruction_loss: 3.6605
# Epoch 15/100
# 12/12 [==============================] - 2s 187ms/step - loss: 4.0011 - reconstruction_loss: 3.6374
# Epoch 16/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.9873 - reconstruction_loss: 3.6130
# Epoch 17/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.8923 - reconstruction_loss: 3.6077
# Epoch 18/100
# 12/12 [==============================] - 2s 195ms/step - loss: 3.8675 - reconstruction_loss: 3.6043
# Epoch 19/100
# 12/12 [==============================] - 2s 179ms/step - loss: 3.5729 - reconstruction_loss: 3.6002
# Epoch 20/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.6673 - reconstruction_loss: 3.6018
# Epoch 21/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.9052 - reconstruction_loss: 3.6049
# Epoch 22/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.8340 - reconstruction_loss: 3.5981
# Epoch 23/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7569 - reconstruction_loss: 3.5927
# Epoch 24/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.8323 - reconstruction_loss: 3.5923
# Epoch 25/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.6785 - reconstruction_loss: 3.5902
# Epoch 26/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.9882 - reconstruction_loss: 3.5934
# Epoch 27/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.8973 - reconstruction_loss: 3.5934
# Epoch 28/100
# 12/12 [==============================] - 2s 184ms/step - loss: 4.0435 - reconstruction_loss: 3.5940
# Epoch 29/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.8006 - reconstruction_loss: 3.5886
# Epoch 30/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.7884 - reconstruction_loss: 3.5889
# Epoch 31/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.5489 - reconstruction_loss: 3.5861
# Epoch 32/100
# 12/12 [==============================] - 2s 195ms/step - loss: 3.7668 - reconstruction_loss: 3.5872
# Epoch 33/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.7787 - reconstruction_loss: 3.5858
# Epoch 34/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.6927 - reconstruction_loss: 3.5868
# Epoch 35/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.9432 - reconstruction_loss: 3.5824
# Epoch 36/100
# 12/12 [==============================] - 2s 200ms/step - loss: 3.8308 - reconstruction_loss: 3.5858
# Epoch 37/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.6506 - reconstruction_loss: 3.5844
# Epoch 38/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.8623 - reconstruction_loss: 3.5846
# Epoch 39/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.7314 - reconstruction_loss: 3.5803
# Epoch 40/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.8427 - reconstruction_loss: 3.5820
# Epoch 41/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.9447 - reconstruction_loss: 3.5836
# Epoch 42/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.9758 - reconstruction_loss: 3.5805
# Epoch 43/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.6973 - reconstruction_loss: 3.5784
# Epoch 44/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.7062 - reconstruction_loss: 3.5812
# Epoch 45/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.7492 - reconstruction_loss: 3.5834
# Epoch 46/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.8260 - reconstruction_loss: 3.5771
# Epoch 47/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.7079 - reconstruction_loss: 3.5770
# Epoch 48/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.7351 - reconstruction_loss: 3.5734
# Epoch 49/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.9002 - reconstruction_loss: 3.5749
# Epoch 50/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.7071 - reconstruction_loss: 3.5746
# Epoch 51/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.8026 - reconstruction_loss: 3.5747
# Epoch 52/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.9460 - reconstruction_loss: 3.5714
# Epoch 53/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.9004 - reconstruction_loss: 3.5702
# Epoch 54/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.9038 - reconstruction_loss: 3.5687
# Epoch 55/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.7436 - reconstruction_loss: 3.5677
# Epoch 56/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.7546 - reconstruction_loss: 3.5676
# Epoch 57/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.7798 - reconstruction_loss: 3.5606
# Epoch 58/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.7904 - reconstruction_loss: 3.5616
# Epoch 59/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.7581 - reconstruction_loss: 3.5585
# Epoch 60/100
# 12/12 [==============================] - 2s 187ms/step - loss: 3.9041 - reconstruction_loss: 3.5580
# Epoch 61/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.8619 - reconstruction_loss: 3.5562
# Epoch 62/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.8172 - reconstruction_loss: 3.5539
# Epoch 63/100
# 12/12 [==============================] - 2s 196ms/step - loss: 3.6383 - reconstruction_loss: 3.5511
# Epoch 64/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.5498 - reconstruction_loss: 3.5456
# Epoch 65/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.7925 - reconstruction_loss: 3.5431
# Epoch 66/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.6939 - reconstruction_loss: 3.5394
# Epoch 67/100
# 12/12 [==============================] - 3s 212ms/step - loss: 3.9997 - reconstruction_loss: 3.5377
# Epoch 68/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.8097 - reconstruction_loss: 3.5271
# Epoch 69/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.8083 - reconstruction_loss: 3.5240
# Epoch 70/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.8363 - reconstruction_loss: 3.5112
# Epoch 71/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.9851 - reconstruction_loss: 3.4984
# Epoch 72/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.5858 - reconstruction_loss: 3.4800
# Epoch 73/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.6393 - reconstruction_loss: 3.4444
# Epoch 74/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.6728 - reconstruction_loss: 3.4095
# Epoch 75/100
# 12/12 [==============================] - 2s 180ms/step - loss: 3.5172 - reconstruction_loss: 3.3837
# Epoch 76/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.6216 - reconstruction_loss: 3.3582
# Epoch 77/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.4249 - reconstruction_loss: 3.3460
# Epoch 78/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.4409 - reconstruction_loss: 3.3164
# Epoch 79/100
# 12/12 [==============================] - 2s 184ms/step - loss: 3.5698 - reconstruction_loss: 3.3025
# Epoch 80/100
# 12/12 [==============================] - 2s 185ms/step - loss: 3.5506 - reconstruction_loss: 3.2954
# Epoch 81/100
# 12/12 [==============================] - 2s 188ms/step - loss: 3.5908 - reconstruction_loss: 3.2688
# Epoch 82/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.4573 - reconstruction_loss: 3.2722
# Epoch 83/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.4380 - reconstruction_loss: 3.2379
# Epoch 84/100
# 12/12 [==============================] - 2s 182ms/step - loss: 3.3227 - reconstruction_loss: 3.2245
# Epoch 85/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.4019 - reconstruction_loss: 3.2004
# Epoch 86/100
# 12/12 [==============================] - 2s 181ms/step - loss: 3.4317 - reconstruction_loss: 3.1818
# Epoch 87/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.3877 - reconstruction_loss: 3.1724
# Epoch 88/100
# 12/12 [==============================] - 2s 203ms/step - loss: 3.4390 - reconstruction_loss: 3.1598
# Epoch 89/100
# 12/12 [==============================] - 2s 198ms/step - loss: 3.2836 - reconstruction_loss: 3.1409
# Epoch 90/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.2986 - reconstruction_loss: 3.1262
# Epoch 91/100
# 12/12 [==============================] - 2s 197ms/step - loss: 3.3719 - reconstruction_loss: 3.1145
# Epoch 92/100
# 12/12 [==============================] - 2s 191ms/step - loss: 3.2489 - reconstruction_loss: 3.0927
# Epoch 93/100
# 12/12 [==============================] - 2s 193ms/step - loss: 3.1988 - reconstruction_loss: 3.0708
# Epoch 94/100
# 12/12 [==============================] - 3s 208ms/step - loss: 3.1300 - reconstruction_loss: 3.0501
# Epoch 95/100
# 12/12 [==============================] - 2s 186ms/step - loss: 3.2801 - reconstruction_loss: 3.0276
# Epoch 96/100
# 12/12 [==============================] - 2s 183ms/step - loss: 3.1979 - reconstruction_loss: 3.0296
# Epoch 97/100
# 12/12 [==============================] - 2s 189ms/step - loss: 3.1244 - reconstruction_loss: 3.0179
# Epoch 98/100
# 12/12 [==============================] - 2s 194ms/step - loss: 3.2444 - reconstruction_loss: 2.9918
# Epoch 99/100
# 12/12 [==============================] - 2s 190ms/step - loss: 3.1711 - reconstruction_loss: 2.9676
# Epoch 100/100
# 12/12 [==============================] - 2s 192ms/step - loss: 3.1411 - reconstruction_loss: 2.9193
